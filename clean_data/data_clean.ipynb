# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import re

# %%
# !pip3 install --user enelvo

# %%
unwanted_words =  [
  "xxxcccxxx",
  "ososoosososiz",
  "cjjfgjkklo",
  "ghhghjjhh",
  "gjjkjh",
  "hjhhjkkjbk",
  "bjkklmkkk",
  "wahlglobal",
  "hiperfocal",
  "ççççççç",
  "cozivapore",
  "chromecast",
  "xxxxccc",
  "xxxccc",
  "hxhchcvh",
  "buddemeyer",
  "jhgfgbvh",
  "maisblush",
  "eleteobest",
  "blackfriday",
  "mastertronic",
  "mastertronic",
  "mastertronic",
  "snapdradon",
  "mastertronic",
  "corrediebdeu",
  "lixolixolixo",
  "humghkkkll",
  "phonestation",
  "thrfhkh",
  "lojasfascina",
  "lojasfascina",
  "jmmnbffcv",
  "superfamicon",
  "blueetooth",
  "superouvminhas",
  "olhomêtro",
  "anticoagulante",
  "boooóooóo",
  "mostrandoletra",
  "buddemayer",
  "pedidovdia",
  "blackfriday",
  "roupiroupinhas",
  "superrecomendo",
  "playskool",
  "rfspokwtgpop",
  "fgggtvvvdvvvsf",
  "kameramera",
  "xxxxcxxxzzz",
  "iiixxx",
  "maravycherry",
  "optronics",
  "quantochip",
  "desencrustante",
  "compraremédio",
  "flashlimp",
  "aprovadisssimo",
  "gfdgsdf",
  "sdfgsdfg",
  "sdfgsdf",
  "chapolinstore",
  "overpriced",
  "fridayfriday",
  "friendships",
  "consectetur",
  "adipiscing",
  "ullamcorper",
  "phasellus",
  "dddfffdfff",
  "watshapp",
  "cliquebooks",
  "chromecast",
  "chromecast",
  "npigijerihg",
  "flashlimp",
  "antirreflexo",
  "blackfriday",
  "xxxxdxxxdxd",
  "altoflntr",
  "emanquecíeis",
  "airfriers",
  "autolimpeza",
  "frontiline",
  "hhhjjj",
  "ghgcvhj",
  "hgdddbk",
  "chromecast",
  "flashlimp",
  "jxfdkjg",
  "jsfdfdçkjç",
  "lktgfkhfgl",
  "bodygroom",
  "mercadolivre",
  "antiaderencia",
  "titâniocelular",
  "aaaggghhhjjj",
  "nvlddmkm",
  "akdsfjhasd",
  "fhasdjkhf",
  "asdjfhasd",
  "sdfhjashdfa",
  "dfiasjidfj",
  "xxxxcc",
  "chromecast",
  "buddemeyer",
  "hjjkgj",
  "dffgghhhjjjkk",
  "muiiitooo",
  "antiaderência",
  "vibroaction",
  "anericaricanas",
  "turbopower",
  "bommmlllmm",
  "freezerseria",
  "aprovadissimo",
  "playatation",
  "ccdcddd",
  "flashlimp",
  "somatodrol",
  "gfddghjhfdd",
  "ggddghjhf",
  "hgdddfhhfddh",
  "bhfdfjufdcb",
  "jgfdgjjjhc",
  "vghjjjhfddgjn",
  "vgdfhjfdf",
  "vhfddfgggvv",
  "flashlimp",
  "buddemeyer",
  "hidralmarchi",
  "yyyxxx",
  "yyyxxx",
  "maniavirtual",
  "chromecast",
  "paguipagui",
  "benefíciotodos",
  "sullenberger",
  "mastertronic",
  "megacomemmerce",
  "mastertronic",
  "buddemeyer",
  "ssdsddd",
  "pppkkkhhh",
  "bluetooty",
  "bluetooty",
  "smartfhone",
  "zbnxjka",
  "scgblyhz",
  "vchjszdhvcszdv",
  "maisfacil",
  "bklgdnlkjglç",
  "mnfsdjkls",
  "kdmeuchip",
  "profutochegou",
  "bluethooth",
  "asgrgdfsg",
  "ffdgdfgdfgas",
  "dfagdafgs",
  "dsfjhespofjf",
  "sfjseporuwt",
  "hometeather",
  "hometeather",
  "watchfaces",
  "hoponopono",
  "zmkkksksk",
  "ookkkaksjs",
  "mamamdkkwkqkw",
  "skakmama",
  "chromecast",
  "chromecast",
  "lllkkk",
  "mjuyyyom",
  "mnnnhyy",
  "mnbvcx",
  "mmnbbf",
  "trocaobrigada",
  "aprovadissimo",
  "gosteimuito",
  "proconporque",
  "samgsung",
  "trocachegou",
  "dachshund",
  "openmandriva",
  "maravicelente",
  "aprovadissimo",
  "mandamensagem",
  "optimemory",
  "klskdieieiei",
  "nenenrjhrh",
  "kakajsj",
  "micropreços",
  "ssuuupeerrr",
  "novadigital",
  "nextflix",
  "huuuúuuuúmuito",
  "xxxcxxxc",
  "xxxdddxxx",
  "micropreços",
  "essanporcaria",
  "marketpalce",
  "fortineletro",
  "autopreparador",
  "kiarostami",
  "adoreipotencia",
  "upscalling",
  "bommmbommm",
  "wesgsgdagr",
  "claudiomário",
  "pequenonpara",
  "flashlimp",
  "xxxvvv",
  "mobcomestore",
  "nnnnaaaooo",
  "retoiluminadas",
  "comprecarshop",
  "comprecarshop",
  "comprecarshop",
  "megacommerce",
  "smarthphones",
  "smarthphone",
  "retroluminoso",
  "hhshsbbhshshhs",
  "bbbbdhus",
  "snjjjejidhsu",
  "zjhsdueh",
  "aprovadissimo",
  "gjallarhorn",
  "hixxxbbb",
  "madeiramadeira",
  "globorural",
  "bluetooh",
  "aromaterapeuta",
  "belezanaweb",
  "uygbiyovb",
  "ptudotoglhkd",
  "otfirihjdi",
  "megacommerce",
  "threadware",
  "wooomwooom",
  "faststorebr",
  "abrireceber",
  "paramaçônicas",
  "pedaleagora",
  "chromecast",
  "bluethoth",
  "bluethoh",
  "directlofg",
  "corpicorpinho",
  "produtoótimo",
  "produtoótimo",
  "produtoótimo",
  "produtoótimo",
  "produtoótimo",
  "produtoótimo",
  "madeiramadeira",
  "novadigital",
  "bluetooh",
  "galditech",
  "frequencímetro",
  "microneedle",
  "mengshahayd",
  "battlegrounds",
  "chromecast",
  "spreadtrum",
  "centercell",
  "buddemyer",
  "xxxxcxccxxx",
  "mirroring",
  "mirroring",
  "lsjifmbodp",
  "meusmartfone",
  "badfbadbf",
  "namvampv",
  "novadigital",
  "smartfhone",
  "cooommmprrra",
  "entúteisera",
  "eastshop",
  "dhsysbdof",
  "shdnfbr",
  "djidjdkd",
  "sjdidjd",
  "sjdidjsbs",
  "fnfjdndbd",
  "fkfifndjd",
  "dnfjdidndn",
  "assabonetado",
  "dasfsdsggg",
  "buddemeyer",
  "nããããooo",
  "novinhaszapzap",
  "chromecast",
  "whattsapp",
  "utilarshop",
  "upsacalling",
  "upscalling",
  "directstock",
  "schwarzkopf",
  "chromecast",
  "superrecomendo",
  "valdineide",
  "fortineletro",
  "dfgjihfeesfjj",
  "dfghtewafvnjg",
  "pontualissima",
  "upsaccilng",
  "nipponflex",
  "buddemeyer",
  "buddemeyer",
  "retroiluminado",
  "funconabbai",
  "masterchef",
  "paguedepois",
  "tupperware",
  "trikxerinox",
  "bbbeauty",
  "usadoouço",
  "fffkkmmcnwopfn",
  "wponfpwon",
  "upfitness",
  "buddemeyer",
  "estanqueidade",
  "philipshave",
  "directlong",
  "whatssapp",
  "monstertrok",
  "fracaosimha",
  "omundodatutty",
  "omundodatutty",
  "omundodatutty",
  "madeiramadeira",
  "ruimtambém",
  "czcpsafz",
  "lkkmczc",
  "czclkzlxcz",
  "cxzxczxcz",
  "mengshahayd",
  "totalexpress",
  "philipsvalita",
  "rotterman",
  "grandstream",
  "bluethoo",
  "shadowhaw",
  "ssangyoung",
  "madeiramadeira",
  "overbumper",
  "brunopstart",
  "gdtgthb",
  "dlkgbjmd",
  "bmzdtfp",
  "bmhçlbmdfz",
  "çflhkç",
  "megacommerce",
  "disporpocional",
  "gosteiuito",
  "thrustemaster",
  "activosion",
  "masterchef",
  "popsocket",
  "otimocusto",
  "neurofeeback",
  "buddemeyer",
  "buddemeyer",
  "ufgkjdfjkknk",
  "fgjkcdtikbcv",
  "vczxvkvxsxfh",
  "gghnvdg",
  "ghhvdth",
  "foyxoyxoydoy",
  "doydoydoyxoyc",
  "fphfoydydoyd",
  "ywjjbkp",
  "nndndjdj",
  "nndndjdj",
  "nndndjdj",
  "hjhjhjhjhjhjh",
  "baixovolume",
  "bpewifh",
  "certotalvez",
  "dlkfkf",
  "smartefone",
  "postcrossers",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "gameteczone",
  "xccxxxcxxx",
  "gorilaglass",
  "uigygjkl",
  "tfghfghgf",
  "topêêêêêêêêêêê",
  "rápidrápida",
  "xiaomiii",
  "buddemeyer",
  "skydiver",
  "booollill",
  "xxxhkgevyj",
  "chromatique",
  "chromatique",
  "testomaster",
  "sonicmaster",
  "hdhdbdb",
  "dydhdbdhdydhd",
  "rhinostore",
  "consectetur",
  "adipiscing",
  "adipiscing",
  "ssshhhooowww",
  "shopdiaadia",
  "shopclik",
  "shopclik",
  "shopclik",
  "acqualimp",
  "booommmnm",
  "ficaenrolando",
  "jdjfueueueje",
  "jhgsneiv",
  "sojrvciksnsb",
  "gallagher",
  "jshdusn",
  "ndidkeneje",
  "ydusjskdi",
  "liebesborn",
  "gorillaglass",
  "superperfeito",
  "bluethooth",
  "antiresíduos",
  "sdfbvabafdbafb",
  "afbdvfva",
  "fgsdfgn",
  "hgbnhgsg",
  "dgafgfghgfh",
  "gfhsdfsdfg",
  "kljyiugb",
  "gigiguyhoioo",
  "gtgtggg",
  "jfufhdk",
  "jdjdjdjjjd",
  "dhhdjhd",
  "airfryier",
  "cfgbrtgbg",
  "superrecomendo",
  "lojamatel",
  "lojamatel",
  "peltierplacas",
  "whatshap",
  "asssaaasasss",
  "muitadificulda",
  "taglierini",
  "technobuy",
  "laklsdjfl",
  "flahsdfasdf",
  "asedfsdfas",
  "mktplace",
  "chromecast",
  "pontualissima",
  "emailnresponde",
  "okokokokokok",
  "oneconnect",
  "produtochegoi",
  "whatszaap",
  "ficoulinda",
  "shopclik",
  "condicondições",
  "yaraferreira",
  "hometheater",
  "hometheater",
  "esmartfone",
  "fhzdfsgs",
  "sasdddaaa",
  "optimemory",
  "cellsysten",
  "buddemeyer",
  "kdjdhdhsjqias",
  "jdjdjsjsjs",
  "sjsjsksksksks",
  "jdjdjsjsjs",
  "sjsjsjsks",
  "sjsjsjsks",
  "sjsjsjsks",
  "sjsjsjsks",
  "esletrostory",
  "watercooler",
  "technobuy",
  "vivalinux",
  "playonlinux",
  "fubciobanebto",
  "technobuy",
  "parafuzadeira",
  "bluetótimo",
  "megacomerce",
  "neperianamente",
  "netlflix",
  "fmoqygpn",
  "macfadyen",
  "analogsync",
  "muiiitooo",
  "cliquebooks",
  "jjjhgjghjj",
  "gdfgfdgfdgfd",
  "fgfdfdgdf",
  "ssddssdsd",
  "sddsdsdsds",
  "produtogostei",
  "chromecast",
  "chromecast",
  "mirascreen",
  "blackwidow",
  "blackwidow",
  "jxhsyoypgk",
  "kvjfufn",
  "hfuficjcj",
  "jfjcjcjcj",
  "tcyvububuv",
  "googledrive",
  "novadgital",
  "novadigital",
  "ḿgoreǵoromg",
  "orlistate",
  "blackscreen",
  "anrricsnss",
  "bluetoot",
  "lohoihoihoih",
  "knoihoii",
  "retroiluminado",
  "dachshund",
  "avfrustacao",
  "antirreflexo",
  "quecwuebrar",
  "ressístémsiar",
  "silêmçioza",
  "superconfiavel",
  "unicpharma",
  "jkvsdvk",
  "ninguememmm",
  "vitalessence",
  "eucafloor",
  "eucafloor",
  "smarttphone",
  "rafinhashop",
  "retroiluminado",
  "mirroring",
  "chromecast",
  "chromecast",
  "mirascreen",
  "peeessiiimaaa",
  "antireflexo",
  "utildecor",
  "mirroring",
  "waterdeep",
  "mercadolivre",
  "chromecast",
  "chromecast",
  "snapfill",
  "nnnmmmnmnnn",
  "magazinevoce",
  "magazinevoce",
  "gorilaglass",
  "technobuy",
  "totschnig",
  "antireflexo",
  "fnrnjrvnjr",
  "rvnrinvrnvr",
  "vnrvnrivnrivnf",
  "marketshare",
  "bruzundangas",
  "puuutzzz",
  "fuininformada",
  "xxxxzzzxxxzzz",
  "comendadissimo",
  "nanochip",
  "mmmbbbmmmnnn",
  "aprovadissíma",
  "vitalessence",
  "smarthphone",
  "aprovadissimo",
  "automassagear",
  "flashlimp",
  "vvvxxx",
  "dsssfggvbnnn",
  "jnnnçojl",
  "jjjhhuuu",
  "ginecomastia",
  "shopmartins",
  "shopmartins",
  "shopmartins",
  "shopmartins",
  "marketingplace",
  "hghghghg",
  "magazinevoce",
  "hhihihohoh",
  "bigigigih",
  "jcigigigigih",
  "alphavile",
  "nãoestornaram",
  "budermayer",
  "budermayer",
  "escriturística",
  "dactecnologi",
  "cxcccvv",
  "condicondições",
  "acdevolucao",
  "geekyard",
  "meutouyuto",
  "mailonline",
  "jhjhkh",
  "khkhkh",
  "jhgjgj",
  "gameteczone",
  "vidrocomprei",
  "jsjhdbdhhdhrb",
  "gsvhjdnbdbrbbd",
  "jdjdhhehdhrbrj",
  "gshshvssv",
  "clickbook",
  "miliamperes",
  "fasedddasfff",
  "aaaaaaaa",
  "phytoervas",
  "smartfhone",
  "watercoolers",
  "xicaxicabum",
  "fiipronil",
  "retroiluminado",
  "muuuitooo",
  "aprovadissimo",
  "nanoshield",
  "smarthphone",
  "alliexpress",
  "situaçãozona",
  "ammmeeeiii",
  "vivendalazer",
  "dnkjsbhsbkjdb",
  "kjsahbf",
  "skfbsibjdkljsb",
  "kjdbskjbdkjsb",
  "antirreflexo",
  "tempoespero",
  "retroiluminado",
  "bhfdddfcgn",
  "nnhfff",
  "bhfdssdf",
  "hgsdhjhvvh",
  "jgccxfghk",
  "ngxgiyb",
  "muuiittoo",
  "antiaderencia",
  "turbopower",
  "buddemeyer",
  "muuuiiitttooo",
  "xxxcccxxx",
  "flashlimp",
  "xxxxcadeiras",
  "battlegrouns",
  "sylocimol",
  "cvbbvadfgrgfg",
  "sdgsrgsdfgsdg",
  "muuuiiitttooo",
  "miliamperes",
  "miliamperes",
  "nadiraparelho",
  "nadiraparelho",
  "nadiraparelho",
  "nadiraparelho",
  "nadiraparelho",
  "nadiraparelho",
  "nadiraparelho",
  "nadiraparelho",
  "telecineplay",
  "jjrhrhtj",
  "tkktjtj",
  "tjrjjjk",
  "microretifica",
  "imitaçãonada",
  "djkjdskjdsksjd",
  "blackwidow",
  "elgscreen",
  "fingerlings",
  "chromoscat",
  "madeiramadeira",
  "jonaslymaa",
  "neofibrine",
  "ŕrrrenfiahhh",
  "uhhhuu",
  "bombomniere",
  "futfanatis",
  "quickcharger",
  "vendodtudo",
  "çxlxxx",
  "spherulites",
  "spherulites",
  "lashidemodal",
  "aprovadissimo",
  "sadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "sasadsaodk",
  "lsaksdl",
  "bemnrapido",
  "commmpremmm",
  "novadigital",
  "aprovadissimo",
  "technobuy",
  "rttydtmkl",
  "gbwdfbg",
  "acquapump",
  "choicemmed",
  "leroymerlin",
  "chromecast",
  "smartfhone",
  "mengshahyd",
  "antiaderencia",
  "sjahhusahu",
  "sygygasgysa",
  "buasugsaguugsa",
  "igdafgbdsf",
  "flequixivel",
  "triptofano",
  "hhjgdll",
  "bonitotecido",
  "bonitotecido",
  "bonitotecido",
  "bonitotecido",
  "xxxvvvmmm",
  "yhjkfghjg",
  "fhjgmdfh",
  "sfsafhgfzbx",
  "ebomcomprar",
  "vagabunbissima",
  "rottweilers",
  "textyoghddd",
  "colchãozera",
  "lllooolooolll",
  "mirroring",
  "gduebhyhemidjd",
  "uydhduydnuchjr",
  "uurjcyhekutr",
  "udhvfijfekjd",
  "dudgrkjxyjerb",
  "uebfyhdkr",
  "hrbjxuyfejud",
  "tttoooppp",
  "smarthphone",
  "wathsapp",
  "dtstrudialog",
  "antirreflexo",
  "antirreflexo",
  "niazitex",
  "chateadissima",
  "xxxcccxxx",
  "fecheclair",
  "esteirasemanas",
  "boaaabbbobbb",
  "globalexpress",
  "naaadfffg",
  "directstock",
  "directstock",
  "bbbbnbbb",
  "smartfhone",
  "bananafoto",
  "bananafoto",
  "ugivivigigivg",
  "smartfhone",
  "hipppeeer",
  "globalhome",
  "wastzapp",
  "estacatendendo",
  "whatssapp",
  "platinumvendas",
  "parafuzadeira",
  "touchscrenn",
  "jdduivjoisston",
  "roccaporena",
  "muiiitooo",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "aindatestando",
  "optimemory",
  "mastertronic",
  "orlistate",
  "unicpharma",
  "sfgasfha",
  "agsgwgwdfadf",
  "dfasdgf",
  "gadsfdsga",
  "aprovadissimo",
  "bemestarsexual",
  "aresfrequeira",
  "kjcgbvbcljha",
  "asbcvklja",
  "perfeitonpara",
  "viagemfazendo",
  "cheaperini",
  "nidavellir",
  "nããããããão",
  "lightroom",
  "esperavagostei",
  "esperavagostei",
  "esperavagostei",
  "ótimaqualidade",
  "muuuiiitttooo",
  "blutooth",
  "lenovorola",
  "trasnlaguna",
  "parecrvlija",
  "prósdocimo",
  "novadigital",
  "reuimruim",
  "euroessence",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "produtogostei",
  "totalexpress",
  "gorilaglass",
  "aggregation",
  "bluethooth",
  "chromecast",
  "chromecast",
  "aprovadissimo",
  "madeiramadeira",
  "onprotudo",
  "soundigital",
  "hhhhbbb",
  "fffgggh",
  "pacabácôpequi",
  "marrycruz",
  "dessepisionado",
  "nidavellir",
  "yggdrasil",
  "sjskzkz",
  "sksjzj",
  "sjsjsjsbz",
  "snsjsjsjzj",
  "snsjsjsj",
  "shsjsjsb",
  "comoconsumidor",
  "jshcicuudjbx",
  "excelentepquem",
  "houseshop",
  "monsterstok",
  "monsterstok",
  "freesync",
  "preeetttooo",
  "magazinevoce",
  "magazinevoce",
  "magazinevoce",
  "jfjfjgkfk",
  "otimoxxx",
  "muiiitooo",
  "metalpack",
  "steelbook",
  "mercadolivre",
  "mercadolivre",
  "thormontina",
  "mastertronic",
  "antiaderencia",
  "blackscreen",
  "stormbreaker",
  "nildavellir",
  "chinguelingues",
  "intersolucao",
  "nidavellir",
  "parabguardar",
  "minhaborelha",
  "novadigital",
  "stormbreaker",
  "muiiitooo",
  "deuzulivre",
  "orodruin",
  "chromecast",
  "steelcase",
  "buddemeryer",
  "buzztech",
  "omsmartphone",
  "douradocelular",
  "maltodextrina",
  "axmfresstyle",
  "monsterstok",
  "refurbush",
  "buddemeyer",
  "chromecast",
  "millenium",
  "antiaderencia",
  "dddjjj",
  "utildecor",
  "nidavellir",
  "nidavellir",
  "ótimooooooo",
  "hfdegnkkkj",
  "hgbhtgbhjjy",
  "reprovadissimo",
  "bluetoth",
  "lihgtroom",
  "geradorzinho",
  "chromecast",
  "canaldaodonto",
  "canaldaodonto",
  "toothpast",
  "smsrtphone",
  "blackscreen",
  "desejavaespero",
  "shocklight",
  "tsaoshin",
  "aaasssddd",
  "aprovadisdoma",
  "bbbeauty",
  "nidavellir",
  "fffkdjsn",
  "sksjdjdfk",
  "primeiracompra",
  "sndjdjd",
  "muiiitooo",
  "aparelhofacil",
  "otimoxxx",
  "quequeriamso",
  "yorkishire",
  "touchscream",
  "readybooster",
  "buddemeyer",
  "blackfriday",
  "ãmcamacma",
  "spççsljldjfaãs",
  "dlmãclçamca",
  "brnfoods",
  "aprovadissimo",
  "upscalling",
  "ltyiuoipo",
  "dfghjklçjklç",
  "zxcbnzx",
  "mdmxmbll",
  "lbdçlgb",
  "diabqbentregou",
  "aprovadissimo",
  "agoravvvnão",
  "humhumatem",
  "antideslizante",
  "smartpfone",
  "hhghhhbhh",
  "hggghhh",
  "cariocadecor",
  "parareconectar",
  "valeuuujuuu",
  "novadigital",
  "yousafzai",
  "pardesemvolver",
  "raylanderson",
  "hidralycollor",
  "buddemeyer",
  "ficooobonitooo",
  "monsterstok",
  "hhhhjjjknvvb",
  "msgpedind",
  "adoreiiieu",
  "aprovadissimo",
  "gsdgdsggg",
  "muuuiiitttooo",
  "smartephone",
  "sdfghjoç",
  "sdfghjklç",
  "sdfghjklç",
  "triptofano",
  "muitofácil",
  "weareable",
  "megacommerce",
  "gotchagotcha",
  "thftjhgfhjf",
  "tjtjft",
  "smartphene",
  "skdofogfd",
  "rollerbal",
  "diejejjehebehr",
  "plystation",
  "dutyfree",
  "chromecast",
  "pontualissima",
  "aquicessivel",
  "smartview",
  "mercadolivre",
  "insastifacao",]

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 52.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
url = 'https://github.com/americanas-tech/b2w-reviews01/blob/main/B2W-Reviews01.csv'
df = pd.read_csv(url, error_bad_lines=False)
df = df.dropna(subset=['review_text'])
df = df.drop_duplicates(subset=['review_text'])

# %%
df['review_text'].to_csv('input_enelvo_reviews.txt', index=False, header=False)

# %%
# !python3 -m enelvo --sanitize --tokenizer readable --input input_enelvo_reviews.txt --output output_enelvo_reviews.txt

# %%
df_enelvo = pd.read_csv("output_enelvo_reviews.txt", header=None, encoding='utf-8')
# Out:
#                                                        0
# 0      estou contente com a compra entrega rápida o ú...
# 1      por apenas ar 1994 20 eu consegui comprar esse...
# 2      supera em agilidade e praticidade outras panel...
# 3      meu filho amou parece de verdade com tantos de...
# 4      a entrega foi no prazo as americanas estão de ...
# ...                                                  ...
# 81965  prático e sem necessidade de instalação basta ...
# 81966  a máquina cumpre o que promete e é bem silenci...
# 81967  o parafuso é muito bom mas não é informado a q...
# 81968  comprei a baby alive e fiquei impressionada co...
# 81969  eu nunca recebi o produto dessa forma se for p...
#
# [81970 rows x 1 columns]

# %%
columns_to_keep = ['review_text', 'enelvo_reviews', 'overall_rating']
df = df[columns_to_keep]
# Out:
# <ipython-input-20-ff8b76563035>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/B2W-Reviews01_enelvo.csv")
#                                          review_text  \
# 0  Estou contente com a compra entrega rápida o ú...
# 1  Por apenas R$1994.20,eu consegui comprar esse ...
# 2  SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANEL...
# 3  MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS D...
# 4  A entrega foi no prazo, as americanas estão de...
#
#                                       enelvo_reviews  overall_rating
# 0  estar contente com o compra entregar rápido o ...               4
# 1  por apenas , eu conseguir comprar esse li copo...               4
# 2  superar em agilidade e praticidade outro panel...               4
# 3  meu filho amar ! parecer de verdade com tanto ...               4
# 4  o entrega ser em o prazo , o americana estar d...               5

# %%
def preprocess_text(df, unwanted_words):
    df['enelvo_reviews'] = df['enelvo_reviews'].astype(str)
    df.dropna(subset=['enelvo_reviews'], inplace=True)
    df.drop_duplicates(subset=['enelvo_reviews'], inplace=True)
    df['enelvo_reviews'] = df['enelvo_reviews'].apply(lambda x: re.sub(r'\d+', '', x))
    return df

filtered_df = preprocess_text(df, unwanted_words)

# %%
filtered_df.to_csv('b2w_clean_reviews.csv')

# %%
import pandas as pd

df = pd.read_csv('b2w_clean_reviews.csv')
df
# Out:
# <ipython-input-3-18a7365a2aed>:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('b2w_clean_reviews.csv')
#         Unnamed: 0      submission_date  \
# 0                0  2018-01-01 00:11:28
# 1                1  2018-01-01 00:13:48
# 2                2  2018-01-01 00:26:02
# 3                3  2018-01-01 00:35:54
# 4                4  2018-01-01 01:00:28
# ...            ...                  ...
# 125585      128405  2018-05-25 12:43:13
# 125586      128406  2018-05-25 12:44:01
# 125587      128407  2018-05-25 12:47:18
# 125588      128408  2018-05-25 12:48:24
# 125589      128409  2018-05-25 12:51:38
#
#                                               reviewer_id product_id  \
# 0       d0fb1ca69422530334178f5c8624aa7a99da47907c44de...  132532965
# 1       014d6dc5a10aed1ff1e6f349fb2b059a2d3de511c7538a...   22562178
# 2       44f2c8edd93471926fff601274b8b2b5c4824e386ae4f2...  113022329
# ...

# %%
columns = ['review_text', 'enelvo_reviews', 'overall_rating']
df = df[columns]

# %%
def preprocess_text(df, unwanted_words):
    df['clean_reviews'] = df['lemmatized_reviews'].astype(str)
    df['clean_reviews'] = df['clean_reviews'].apply(lambda x: re.sub(r'\d+', '', x))
    df['clean_reviews'] = df['clean_reviews'].apply(lambda x: re.sub(r'http\S+', '', x))
    df['clean_reviews'] = df['clean_reviews'].apply(lambda x: re.sub(r'[\"“”]', '', x))
    df['clean_reviews'] = df['clean_reviews'].str.lower()
    df['clean_reviews'] = df['clean_reviews'].apply(lambda x: ' '.join([word for word in x.split() if word not in unwanted_words]))
    df['clean_reviews'] = df['clean_reviews'].apply(lambda x: ' '.join(x.split()))
    return df

df = preprocess_text(df, unwanted_words)

# %%
df_stop_words.to_csv('new_clean_reviews', index=False)

# %%
def contains_unwanted_words(review):
    return any(word in review for word in unwanted_words)
    df = df[~df['review_text'].apply(contains_unwanted_words)]
    return df

df = filter_reviews(df, unwanted_words)

# %%
lst = []
def rating_to_polarities(rating: int) -> int:
    if rating < 3:
       return 0
    elif rating == 3:
        return 1
    else:
        return 2

clean_data['polarity'] = clean_data['overall_rating'].apply(rating_to_polarities)

# %%
negative = clean_data[clean_data['polarity'] == 0].sample(n=7216)
neutral = clean_data[clean_data['polarity'] == 1].sample(n=7216)
positive = clean_data[clean_data['polarity'] == 2].sample(n=7216)
clean_data = pd.concat([negative, neutral, positive], ignore_index=True)

# %%
train_data, test_data = train_test_split(clen_data, test_size=0.2, stratify=clen_data['polarity'])
test_data, validation_data = train_test_split(test_data, test_size=0.5, stratify=test_data['polarity'])

# %%
train_data.to_csv('train.csv', index=False)
test_data.to_csv('test.csv', index=False)
validation_data.to_csv('val.csv', index=False)
